# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/cs839-project

# %% [markdown]
# # Clone Repo

# %%
# !git clone https://{auth_code}@github.com/spencrr/cs839-project

# %% [markdown]
# # Importing

# %%
# !git pull

# %%
# import

import torch
import numpy as np
import random
import torch.backends.cudnn as cudnn

cudnn.benchmark = True

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# Setting random seeds:
random.seed(123)
np.random.seed(seed=123)
torch.manual_seed(123)

# %% [markdown]
# # Training Models

# %%
from model import classification_training_pipeline

model_type="normal_resnet"
dataset_name="mnist"


classification_training_pipeline(".", model_type, dataset_name, device, epochs=100, lr=0.001)
# Out:
# ==> Building model..

# %% [markdown]
# # Push Changes

# %%
# !git status

# %%
# !git add .

# %%
# !git config user.email "cwdiianni@gmail.com"
# !git commit -m "HELPFUL MESSAGE HERE!!!"
# !git commit -m ""

# %%
# !git push
